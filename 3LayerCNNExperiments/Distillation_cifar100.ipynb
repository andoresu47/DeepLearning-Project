# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from CNN import ThreeLayerConvNet
from model import myModel

from data_utils import unpickle
from ResNet_Tensorflow.utils import load_cifar100
from ResNet_Tensorflow.ResNet import ResNet
from keras.models import Model
from cifar100.cifar_resnet import SmallResNet
from cifar100.cifar100vgg import cifar100vgg

import time
import pickle

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load data
x_train, y_train, x_test, y_test = load_cifar100()

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 100)
# (10000, 32, 32, 3) (10000, 100)

# %%
# Prepare data to train with small model
data = {'X_train': x_train[:49000].transpose(0,3,1,2).copy(), 'y_train': np.argmax(y_train[:49000],axis=1),
        'X_val': x_train[49000:].transpose(0,3,1,2).copy(), 'y_val': np.argmax(y_train[49000:],axis=1),
        'X_test': x_test.transpose(0,3,1,2).copy(), 'y_test': np.argmax(y_test,axis=1),
       }

# %%
print(data['X_train'].shape, data['y_train'].shape)
print(data['X_val'].shape, data['y_val'].shape)
print(data['X_test'].shape, data['y_test'].shape)
# Out:
# (49000, 3, 32, 32) (49000,)
# (1000, 3, 32, 32) (1000,)
# (10000, 3, 32, 32) (10000,)

# %%
print(np.mean(x_train[0]))
# Out:
# 0.2736978722097671

# %%
net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

small_model = myModel(net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      checkpoint_name='checkpoints/small_model_cifar100')
tic = time.time()
small_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(small_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 4.611361
# Saving checkpoint to "checkpoints/small_model_cifar100_epoch_0.pkl"
# (Epoch 0 / 2) train acc: 0.016673; val_acc: 0.010000
# (Iteration 101 / 980) loss: 4.040595
# (Iteration 201 / 980) loss: 3.700560
# (Iteration 301 / 980) loss: 3.088319
# (Iteration 401 / 980) loss: 3.812060
# Saving checkpoint to "checkpoints/small_model_cifar100_epoch_1.pkl"
# (Epoch 1 / 2) train acc: 0.227633; val_acc: 0.209000
# (Iteration 501 / 980) loss: 3.471729
# (Iteration 601 / 980) loss: 3.433722
# (Iteration 701 / 980) loss: 3.290821
# (Iteration 801 / 980) loss: 3.303398
# (Iteration 901 / 980) loss: 3.190131
# Saving checkpoint to "checkpoints/small_model_cifar100_epoch_2.pkl"
# (Epoch 2 / 2) train acc: 0.293041; val_acc: 0.234000
# Execution time:  1476.2186529636383
# Test accuracy: 0.2561

# %%
net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=7,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

small_model = myModel(net, data, 
                      num_epochs=5, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      checkpoint_name='checkpoints/small_model_cifar100_5epoch')
tic = time.time()
small_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(small_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 2450) loss: 4.611355
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_0.pkl"
# (Epoch 0 / 5) train acc: 0.020878; val_acc: 0.026000
# (Iteration 101 / 2450) loss: 3.761836
# (Iteration 201 / 2450) loss: 3.713803
# (Iteration 301 / 2450) loss: 3.501951
# (Iteration 401 / 2450) loss: 3.283360
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_1.pkl"
# (Epoch 1 / 5) train acc: 0.242082; val_acc: 0.197000
# (Iteration 501 / 2450) loss: 3.376592
# (Iteration 601 / 2450) loss: 3.289839
# (Iteration 701 / 2450) loss: 3.061102
# (Iteration 801 / 2450) loss: 2.918731
# (Iteration 901 / 2450) loss: 2.930805
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_2.pkl"
# (Epoch 2 / 5) train acc: 0.306776; val_acc: 0.256000
# (Iteration 1001 / 2450) loss: 3.341122
# (Iteration 1101 / 2450) loss: 3.110064
# (Iteration 1201 / 2450) loss: 3.280368
# (Iteration 1301 / 2450) loss: 2.934712
# (Iteration 1401 / 2450) loss: 2.807596
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_3.pkl"
# (Epoch 3 / 5) train acc: 0.361918; val_acc: 0.268000
# (Iteration 1501 / 2450) loss: 2.832740
# (Iteration 1601 / 2450) loss: 2.864254
# (Iteration 1701 / 2450) loss: 2.461027
# (Iteration 1801 / 2450) loss: 3.215721
# (Iteration 1901 / 2450) loss: 2.410814
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_4.pkl"
# (Epoch 4 / 5) train acc: 0.388143; val_acc: 0.285000
# (Iteration 2001 / 2450) loss: 2.794678
# (Iteration 2101 / 2450) loss: 2.866153
# (Iteration 2201 / 2450) loss: 2.464906
# (Iteration 2301 / 2450) loss: 2.514994
# (Iteration 2401 / 2450) loss: 2.794693
# Saving checkpoint to "checkpoints/small_model_cifar100_5epoch_epoch_5.pkl"
# (Epoch 5 / 5) train acc: 0.436918; val_acc: 0.299000
# Execution time:  6807.12068772316

# %% [markdown]
# # Distill knowledge from ResNet18

# %%
# For being faster pick up file of logit from vgg16
# This model has 87.26% train accuracy and 68.81% test accuracy
logits_train_res18 = unpickle('./ResNet-Tensorflow/resnet18_logits_train.txt')

# %%
# Train small model with distilling from ResNet18
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=5.0,logit_distill=logits_train_res18)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 59.873485
# (Epoch 0 / 2) train acc: 0.012245; val_acc: 0.017000
# (Iteration 101 / 980) loss: 58.004536
# (Iteration 201 / 980) loss: 57.094500
# (Iteration 301 / 980) loss: 56.669959
# (Iteration 401 / 980) loss: 56.520184
# (Epoch 1 / 2) train acc: 0.250633; val_acc: 0.224000
# (Iteration 501 / 980) loss: 56.381089
# (Iteration 601 / 980) loss: 56.571088
# (Iteration 701 / 980) loss: 56.215117
# (Iteration 801 / 980) loss: 55.882912
# (Iteration 901 / 980) loss: 56.269351
# (Epoch 2 / 2) train acc: 0.329918; val_acc: 0.269000
# Execution time:  1548.218759059906
# Test accuracy: 0.2908

# %%
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=2.0,logit_distill=logits_train_res18)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 11.519054
# (Epoch 0 / 2) train acc: 0.026224; val_acc: 0.034000
# (Iteration 101 / 980) loss: 10.375120
# (Iteration 201 / 980) loss: 9.378027
# (Iteration 301 / 980) loss: 8.848267
# (Iteration 401 / 980) loss: 9.114535
# (Epoch 1 / 2) train acc: 0.241388; val_acc: 0.194000
# (Iteration 501 / 980) loss: 8.459070
# (Iteration 601 / 980) loss: 9.038652
# (Iteration 701 / 980) loss: 8.882652
# (Iteration 801 / 980) loss: 8.657711
# (Iteration 901 / 980) loss: 8.091252
# (Epoch 2 / 2) train acc: 0.328714; val_acc: 0.248000
# Execution time:  1549.500007867813
# Test accuracy: 0.285

# %%
# Train small model with distilling from ResNet18
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=20.0,logit_distill=logits_train_res18)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))

# %% [markdown]
# # Distill knowledge from ResNet110

# %%
net_res = SmallResNet(n=18, top_activation=None, weights='./cifar100/resnet-110_cifar100.model.h5')

# %%
net_res.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, None, None, 1 448         input_7[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, None, None, 1 64          conv0[0][0]
# __________________________________________________________________________________________________
# activation_1117 (Activation)    (None, None, None, 1 0           bn0[0][0]
# __________________________________________________________________________________________________
# res1-1x (Conv2D)                (None, None, None, 1 2320        activation_1117[0][0]
# __________________________________________________________________________________________________
# bn1-1x (BatchNormalization)     (None, None, None, 1 64          res1-1x[0][0]
# __________________________________________________________________________________________________
# activation_1118 (Activation)    (None, None, None, 1 0           bn1-1x[0][0]
# __________________________________________________________________________________________________
# res1-1y (Conv2D)                (None, None, None, 1 2320        activation_1118[0][0]
# __________________________________________________________________________________________________
# bn1-1y (BatchNormalization)     (None, None, None, 1 64          res1-1y[0][0]
# __________________________________________________________________________________________________
# add_556 (Add)                   (None, None, None, 1 0           bn1-1y[0][0]
#                                                                  activation_1117[0][0]
# __________________________________________________________________________________________________
# activation_1119 (Activation)    (None, None, None, 1 0           add_556[0][0]
# __________________________________________________________________________________________________
# res1-2x (Conv2D)                (None, None, None, 1 2320        activation_1119[0][0]
# __________________________________________________________________________________________________
# bn1-2x (BatchNormalization)     (None, None, None, 1 64          res1-2x[0][0]
# __________________________________________________________________________________________________
# activation_1120 (Activation)    (None, None, None, 1 0           bn1-2x[0][0]
# __________________________________________________________________________________________________
# res1-2y (Conv2D)                (None, None, None, 1 2320        activation_1120[0][0]
# __________________________________________________________________________________________________
# bn1-2y (BatchNormalization)     (None, None, None, 1 64          res1-2y[0][0]
# __________________________________________________________________________________________________
# add_557 (Add)                   (None, None, None, 1 0           bn1-2y[0][0]
#                                                                  activation_1119[0][0]
# __________________________________________________________________________________________________
# activation_1121 (Activation)    (None, None, None, 1 0           add_557[0][0]
# __________________________________________________________________________________________________
# res1-3x (Conv2D)                (None, None, None, 1 2320        activation_1121[0][0]
# __________________________________________________________________________________________________
# bn1-3x (BatchNormalization)     (None, None, None, 1 64          res1-3x[0][0]
# __________________________________________________________________________________________________
# activation_1122 (Activation)    (None, None, None, 1 0           bn1-3x[0][0]
# __________________________________________________________________________________________________
# res1-3y (Conv2D)                (None, None, None, 1 2320        activation_1122[0][0]
# __________________________________________________________________________________________________
# bn1-3y (BatchNormalization)     (None, None, None, 1 64          res1-3y[0][0]
# __________________________________________________________________________________________________
# add_558 (Add)                   (None, None, None, 1 0           bn1-3y[0][0]
#                                                                  activation_1121[0][0]
# __________________________________________________________________________________________________
# activation_1123 (Activation)    (None, None, None, 1 0           add_558[0][0]
# __________________________________________________________________________________________________
# res1-4x (Conv2D)                (None, None, None, 1 2320        activation_1123[0][0]
# __________________________________________________________________________________________________
# bn1-4x (BatchNormalization)     (None, None, None, 1 64          res1-4x[0][0]
# __________________________________________________________________________________________________
# activation_1124 (Activation)    (None, None, None, 1 0           bn1-4x[0][0]
# __________________________________________________________________________________________________
# res1-4y (Conv2D)                (None, None, None, 1 2320        activation_1124[0][0]
# __________________________________________________________________________________________________
# bn1-4y (BatchNormalization)     (None, None, None, 1 64          res1-4y[0][0]
# __________________________________________________________________________________________________
# add_559 (Add)                   (None, None, None, 1 0           bn1-4y[0][0]
#                                                                  activation_1123[0][0]
# __________________________________________________________________________________________________
# activation_1125 (Activation)    (None, None, None, 1 0           add_559[0][0]
# __________________________________________________________________________________________________
# res1-5x (Conv2D)                (None, None, None, 1 2320        activation_1125[0][0]
# __________________________________________________________________________________________________
# bn1-5x (BatchNormalization)     (None, None, None, 1 64          res1-5x[0][0]
# __________________________________________________________________________________________________
# activation_1126 (Activation)    (None, None, None, 1 0           bn1-5x[0][0]
# __________________________________________________________________________________________________
# res1-5y (Conv2D)                (None, None, None, 1 2320        activation_1126[0][0]
# __________________________________________________________________________________________________
# bn1-5y (BatchNormalization)     (None, None, None, 1 64          res1-5y[0][0]
# __________________________________________________________________________________________________
# add_560 (Add)                   (None, None, None, 1 0           bn1-5y[0][0]
#                                                                  activation_1125[0][0]
# __________________________________________________________________________________________________
# activation_1127 (Activation)    (None, None, None, 1 0           add_560[0][0]
# __________________________________________________________________________________________________
# res1-6x (Conv2D)                (None, None, None, 1 2320        activation_1127[0][0]
# __________________________________________________________________________________________________
# bn1-6x (BatchNormalization)     (None, None, None, 1 64          res1-6x[0][0]
# __________________________________________________________________________________________________
# activation_1128 (Activation)    (None, None, None, 1 0           bn1-6x[0][0]
# __________________________________________________________________________________________________
# res1-6y (Conv2D)                (None, None, None, 1 2320        activation_1128[0][0]
# __________________________________________________________________________________________________
# bn1-6y (BatchNormalization)     (None, None, None, 1 64          res1-6y[0][0]
# __________________________________________________________________________________________________
# add_561 (Add)                   (None, None, None, 1 0           bn1-6y[0][0]
#                                                                  activation_1127[0][0]
# __________________________________________________________________________________________________
# activation_1129 (Activation)    (None, None, None, 1 0           add_561[0][0]
# __________________________________________________________________________________________________
# res1-7x (Conv2D)                (None, None, None, 1 2320        activation_1129[0][0]
# __________________________________________________________________________________________________
# bn1-7x (BatchNormalization)     (None, None, None, 1 64          res1-7x[0][0]
# __________________________________________________________________________________________________
# activation_1130 (Activation)    (None, None, None, 1 0           bn1-7x[0][0]
# __________________________________________________________________________________________________
# res1-7y (Conv2D)                (None, None, None, 1 2320        activation_1130[0][0]
# __________________________________________________________________________________________________
# bn1-7y (BatchNormalization)     (None, None, None, 1 64          res1-7y[0][0]
# __________________________________________________________________________________________________
# add_562 (Add)                   (None, None, None, 1 0           bn1-7y[0][0]
#                                                                  activation_1129[0][0]
# __________________________________________________________________________________________________
# activation_1131 (Activation)    (None, None, None, 1 0           add_562[0][0]
# __________________________________________________________________________________________________
# res1-8x (Conv2D)                (None, None, None, 1 2320        activation_1131[0][0]
# __________________________________________________________________________________________________
# bn1-8x (BatchNormalization)     (None, None, None, 1 64          res1-8x[0][0]
# __________________________________________________________________________________________________
# activation_1132 (Activation)    (None, None, None, 1 0           bn1-8x[0][0]
# __________________________________________________________________________________________________
# res1-8y (Conv2D)                (None, None, None, 1 2320        activation_1132[0][0]
# __________________________________________________________________________________________________
# bn1-8y (BatchNormalization)     (None, None, None, 1 64          res1-8y[0][0]
# __________________________________________________________________________________________________
# add_563 (Add)                   (None, None, None, 1 0           bn1-8y[0][0]
#                                                                  activation_1131[0][0]
# __________________________________________________________________________________________________
# activation_1133 (Activation)    (None, None, None, 1 0           add_563[0][0]
# __________________________________________________________________________________________________
# res1-9x (Conv2D)                (None, None, None, 1 2320        activation_1133[0][0]
# __________________________________________________________________________________________________
# bn1-9x (BatchNormalization)     (None, None, None, 1 64          res1-9x[0][0]
# __________________________________________________________________________________________________
# activation_1134 (Activation)    (None, None, None, 1 0           bn1-9x[0][0]
# __________________________________________________________________________________________________
# res1-9y (Conv2D)                (None, None, None, 1 2320        activation_1134[0][0]
# __________________________________________________________________________________________________
# bn1-9y (BatchNormalization)     (None, None, None, 1 64          res1-9y[0][0]
# __________________________________________________________________________________________________
# add_564 (Add)                   (None, None, None, 1 0           bn1-9y[0][0]
#                                                                  activation_1133[0][0]
# __________________________________________________________________________________________________
# activation_1135 (Activation)    (None, None, None, 1 0           add_564[0][0]
# __________________________________________________________________________________________________
# res1-10x (Conv2D)               (None, None, None, 1 2320        activation_1135[0][0]
# __________________________________________________________________________________________________
# bn1-10x (BatchNormalization)    (None, None, None, 1 64          res1-10x[0][0]
# __________________________________________________________________________________________________
# activation_1136 (Activation)    (None, None, None, 1 0           bn1-10x[0][0]
# __________________________________________________________________________________________________
# res1-10y (Conv2D)               (None, None, None, 1 2320        activation_1136[0][0]
# __________________________________________________________________________________________________
# bn1-10y (BatchNormalization)    (None, None, None, 1 64          res1-10y[0][0]
# __________________________________________________________________________________________________
# add_565 (Add)                   (None, None, None, 1 0           bn1-10y[0][0]
#                                                                  activation_1135[0][0]
# __________________________________________________________________________________________________
# activation_1137 (Activation)    (None, None, None, 1 0           add_565[0][0]
# __________________________________________________________________________________________________
# res1-11x (Conv2D)               (None, None, None, 1 2320        activation_1137[0][0]
# __________________________________________________________________________________________________
# bn1-11x (BatchNormalization)    (None, None, None, 1 64          res1-11x[0][0]
# __________________________________________________________________________________________________
# activation_1138 (Activation)    (None, None, None, 1 0           bn1-11x[0][0]
# __________________________________________________________________________________________________
# res1-11y (Conv2D)               (None, None, None, 1 2320        activation_1138[0][0]
# __________________________________________________________________________________________________
# bn1-11y (BatchNormalization)    (None, None, None, 1 64          res1-11y[0][0]
# __________________________________________________________________________________________________
# add_566 (Add)                   (None, None, None, 1 0           bn1-11y[0][0]
#                                                                  activation_1137[0][0]
# __________________________________________________________________________________________________
# activation_1139 (Activation)    (None, None, None, 1 0           add_566[0][0]
# __________________________________________________________________________________________________
# res1-12x (Conv2D)               (None, None, None, 1 2320        activation_1139[0][0]
# __________________________________________________________________________________________________
# bn1-12x (BatchNormalization)    (None, None, None, 1 64          res1-12x[0][0]
# __________________________________________________________________________________________________
# activation_1140 (Activation)    (None, None, None, 1 0           bn1-12x[0][0]
# __________________________________________________________________________________________________
# res1-12y (Conv2D)               (None, None, None, 1 2320        activation_1140[0][0]
# __________________________________________________________________________________________________
# bn1-12y (BatchNormalization)    (None, None, None, 1 64          res1-12y[0][0]
# __________________________________________________________________________________________________
# add_567 (Add)                   (None, None, None, 1 0           bn1-12y[0][0]
#                                                                  activation_1139[0][0]
# __________________________________________________________________________________________________
# activation_1141 (Activation)    (None, None, None, 1 0           add_567[0][0]
# __________________________________________________________________________________________________
# res1-13x (Conv2D)               (None, None, None, 1 2320        activation_1141[0][0]
# __________________________________________________________________________________________________
# bn1-13x (BatchNormalization)    (None, None, None, 1 64          res1-13x[0][0]
# __________________________________________________________________________________________________
# activation_1142 (Activation)    (None, None, None, 1 0           bn1-13x[0][0]
# __________________________________________________________________________________________________
# res1-13y (Conv2D)               (None, None, None, 1 2320        activation_1142[0][0]
# __________________________________________________________________________________________________
# bn1-13y (BatchNormalization)    (None, None, None, 1 64          res1-13y[0][0]
# __________________________________________________________________________________________________
# add_568 (Add)                   (None, None, None, 1 0           bn1-13y[0][0]
#                                                                  activation_1141[0][0]
# __________________________________________________________________________________________________
# activation_1143 (Activation)    (None, None, None, 1 0           add_568[0][0]
# __________________________________________________________________________________________________
# res1-14x (Conv2D)               (None, None, None, 1 2320        activation_1143[0][0]
# __________________________________________________________________________________________________
# bn1-14x (BatchNormalization)    (None, None, None, 1 64          res1-14x[0][0]
# __________________________________________________________________________________________________
# activation_1144 (Activation)    (None, None, None, 1 0           bn1-14x[0][0]
# __________________________________________________________________________________________________
# res1-14y (Conv2D)               (None, None, None, 1 2320        activation_1144[0][0]
# __________________________________________________________________________________________________
# bn1-14y (BatchNormalization)    (None, None, None, 1 64          res1-14y[0][0]
# __________________________________________________________________________________________________
# add_569 (Add)                   (None, None, None, 1 0           bn1-14y[0][0]
#                                                                  activation_1143[0][0]
# __________________________________________________________________________________________________
# activation_1145 (Activation)    (None, None, None, 1 0           add_569[0][0]
# __________________________________________________________________________________________________
# res1-15x (Conv2D)               (None, None, None, 1 2320        activation_1145[0][0]
# __________________________________________________________________________________________________
# bn1-15x (BatchNormalization)    (None, None, None, 1 64          res1-15x[0][0]
# __________________________________________________________________________________________________
# activation_1146 (Activation)    (None, None, None, 1 0           bn1-15x[0][0]
# __________________________________________________________________________________________________
# res1-15y (Conv2D)               (None, None, None, 1 2320        activation_1146[0][0]
# __________________________________________________________________________________________________
# bn1-15y (BatchNormalization)    (None, None, None, 1 64          res1-15y[0][0]
# __________________________________________________________________________________________________
# add_570 (Add)                   (None, None, None, 1 0           bn1-15y[0][0]
#                                                                  activation_1145[0][0]
# __________________________________________________________________________________________________
# activation_1147 (Activation)    (None, None, None, 1 0           add_570[0][0]
# __________________________________________________________________________________________________
# res1-16x (Conv2D)               (None, None, None, 1 2320        activation_1147[0][0]
# __________________________________________________________________________________________________
# bn1-16x (BatchNormalization)    (None, None, None, 1 64          res1-16x[0][0]
# __________________________________________________________________________________________________
# activation_1148 (Activation)    (None, None, None, 1 0           bn1-16x[0][0]
# __________________________________________________________________________________________________
# res1-16y (Conv2D)               (None, None, None, 1 2320        activation_1148[0][0]
# __________________________________________________________________________________________________
# bn1-16y (BatchNormalization)    (None, None, None, 1 64          res1-16y[0][0]
# __________________________________________________________________________________________________
# add_571 (Add)                   (None, None, None, 1 0           bn1-16y[0][0]
#                                                                  activation_1147[0][0]
# __________________________________________________________________________________________________
# activation_1149 (Activation)    (None, None, None, 1 0           add_571[0][0]
# __________________________________________________________________________________________________
# res1-17x (Conv2D)               (None, None, None, 1 2320        activation_1149[0][0]
# __________________________________________________________________________________________________
# bn1-17x (BatchNormalization)    (None, None, None, 1 64          res1-17x[0][0]
# __________________________________________________________________________________________________
# activation_1150 (Activation)    (None, None, None, 1 0           bn1-17x[0][0]
# __________________________________________________________________________________________________
# res1-17y (Conv2D)               (None, None, None, 1 2320        activation_1150[0][0]
# __________________________________________________________________________________________________
# bn1-17y (BatchNormalization)    (None, None, None, 1 64          res1-17y[0][0]
# __________________________________________________________________________________________________
# add_572 (Add)                   (None, None, None, 1 0           bn1-17y[0][0]
#                                                                  activation_1149[0][0]
# __________________________________________________________________________________________________
# activation_1151 (Activation)    (None, None, None, 1 0           add_572[0][0]
# __________________________________________________________________________________________________
# res1-18x (Conv2D)               (None, None, None, 1 2320        activation_1151[0][0]
# __________________________________________________________________________________________________
# bn1-18x (BatchNormalization)    (None, None, None, 1 64          res1-18x[0][0]
# __________________________________________________________________________________________________
# activation_1152 (Activation)    (None, None, None, 1 0           bn1-18x[0][0]
# __________________________________________________________________________________________________
# res1-18y (Conv2D)               (None, None, None, 1 2320        activation_1152[0][0]
# __________________________________________________________________________________________________
# bn1-18y (BatchNormalization)    (None, None, None, 1 64          res1-18y[0][0]
# __________________________________________________________________________________________________
# add_573 (Add)                   (None, None, None, 1 0           bn1-18y[0][0]
#                                                                  activation_1151[0][0]
# __________________________________________________________________________________________________
# activation_1153 (Activation)    (None, None, None, 1 0           add_573[0][0]
# __________________________________________________________________________________________________
# res2-1x (Conv2D)                (None, None, None, 3 4640        activation_1153[0][0]
# __________________________________________________________________________________________________
# bn2-1x (BatchNormalization)     (None, None, None, 3 128         res2-1x[0][0]
# __________________________________________________________________________________________________
# activation_1154 (Activation)    (None, None, None, 3 0           bn2-1x[0][0]
# __________________________________________________________________________________________________
# res2-1y (Conv2D)                (None, None, None, 3 9248        activation_1154[0][0]
# __________________________________________________________________________________________________
# avg2-1 (AveragePooling2D)       (None, None, None, 1 0           activation_1153[0][0]
# __________________________________________________________________________________________________
# bn2-1y (BatchNormalization)     (None, None, None, 3 128         res2-1y[0][0]
# __________________________________________________________________________________________________
# pad2-1 (ChannelPadding)         (None, None, None, 3 0           avg2-1[0][0]
# __________________________________________________________________________________________________
# add_574 (Add)                   (None, None, None, 3 0           bn2-1y[0][0]
#                                                                  pad2-1[0][0]
# __________________________________________________________________________________________________
# activation_1155 (Activation)    (None, None, None, 3 0           add_574[0][0]
# __________________________________________________________________________________________________
# res2-2x (Conv2D)                (None, None, None, 3 9248        activation_1155[0][0]
# __________________________________________________________________________________________________
# bn2-2x (BatchNormalization)     (None, None, None, 3 128         res2-2x[0][0]
# __________________________________________________________________________________________________
# activation_1156 (Activation)    (None, None, None, 3 0           bn2-2x[0][0]
# __________________________________________________________________________________________________
# res2-2y (Conv2D)                (None, None, None, 3 9248        activation_1156[0][0]
# __________________________________________________________________________________________________
# bn2-2y (BatchNormalization)     (None, None, None, 3 128         res2-2y[0][0]
# __________________________________________________________________________________________________
# add_575 (Add)                   (None, None, None, 3 0           bn2-2y[0][0]
#                                                                  activation_1155[0][0]
# __________________________________________________________________________________________________
# activation_1157 (Activation)    (None, None, None, 3 0           add_575[0][0]
# __________________________________________________________________________________________________
# res2-3x (Conv2D)                (None, None, None, 3 9248        activation_1157[0][0]
# __________________________________________________________________________________________________
# bn2-3x (BatchNormalization)     (None, None, None, 3 128         res2-3x[0][0]
# __________________________________________________________________________________________________
# activation_1158 (Activation)    (None, None, None, 3 0           bn2-3x[0][0]
# __________________________________________________________________________________________________
# res2-3y (Conv2D)                (None, None, None, 3 9248        activation_1158[0][0]
# __________________________________________________________________________________________________
# bn2-3y (BatchNormalization)     (None, None, None, 3 128         res2-3y[0][0]
# __________________________________________________________________________________________________
# add_576 (Add)                   (None, None, None, 3 0           bn2-3y[0][0]
#                                                                  activation_1157[0][0]
# __________________________________________________________________________________________________
# activation_1159 (Activation)    (None, None, None, 3 0           add_576[0][0]
# __________________________________________________________________________________________________
# res2-4x (Conv2D)                (None, None, None, 3 9248        activation_1159[0][0]
# __________________________________________________________________________________________________
# bn2-4x (BatchNormalization)     (None, None, None, 3 128         res2-4x[0][0]
# __________________________________________________________________________________________________
# activation_1160 (Activation)    (None, None, None, 3 0           bn2-4x[0][0]
# __________________________________________________________________________________________________
# res2-4y (Conv2D)                (None, None, None, 3 9248        activation_1160[0][0]
# __________________________________________________________________________________________________
# bn2-4y (BatchNormalization)     (None, None, None, 3 128         res2-4y[0][0]
# __________________________________________________________________________________________________
# add_577 (Add)                   (None, None, None, 3 0           bn2-4y[0][0]
#                                                                  activation_1159[0][0]
# __________________________________________________________________________________________________
# activation_1161 (Activation)    (None, None, None, 3 0           add_577[0][0]
# __________________________________________________________________________________________________
# res2-5x (Conv2D)                (None, None, None, 3 9248        activation_1161[0][0]
# __________________________________________________________________________________________________
# bn2-5x (BatchNormalization)     (None, None, None, 3 128         res2-5x[0][0]
# __________________________________________________________________________________________________
# activation_1162 (Activation)    (None, None, None, 3 0           bn2-5x[0][0]
# __________________________________________________________________________________________________
# res2-5y (Conv2D)                (None, None, None, 3 9248        activation_1162[0][0]
# __________________________________________________________________________________________________
# bn2-5y (BatchNormalization)     (None, None, None, 3 128         res2-5y[0][0]
# __________________________________________________________________________________________________
# add_578 (Add)                   (None, None, None, 3 0           bn2-5y[0][0]
#                                                                  activation_1161[0][0]
# __________________________________________________________________________________________________
# activation_1163 (Activation)    (None, None, None, 3 0           add_578[0][0]
# __________________________________________________________________________________________________
# res2-6x (Conv2D)                (None, None, None, 3 9248        activation_1163[0][0]
# __________________________________________________________________________________________________
# bn2-6x (BatchNormalization)     (None, None, None, 3 128         res2-6x[0][0]
# __________________________________________________________________________________________________
# activation_1164 (Activation)    (None, None, None, 3 0           bn2-6x[0][0]
# __________________________________________________________________________________________________
# res2-6y (Conv2D)                (None, None, None, 3 9248        activation_1164[0][0]
# __________________________________________________________________________________________________
# bn2-6y (BatchNormalization)     (None, None, None, 3 128         res2-6y[0][0]
# __________________________________________________________________________________________________
# add_579 (Add)                   (None, None, None, 3 0           bn2-6y[0][0]
#                                                                  activation_1163[0][0]
# __________________________________________________________________________________________________
# activation_1165 (Activation)    (None, None, None, 3 0           add_579[0][0]
# __________________________________________________________________________________________________
# res2-7x (Conv2D)                (None, None, None, 3 9248        activation_1165[0][0]
# __________________________________________________________________________________________________
# bn2-7x (BatchNormalization)     (None, None, None, 3 128         res2-7x[0][0]
# __________________________________________________________________________________________________
# activation_1166 (Activation)    (None, None, None, 3 0           bn2-7x[0][0]
# __________________________________________________________________________________________________
# res2-7y (Conv2D)                (None, None, None, 3 9248        activation_1166[0][0]
# __________________________________________________________________________________________________
# bn2-7y (BatchNormalization)     (None, None, None, 3 128         res2-7y[0][0]
# __________________________________________________________________________________________________
# add_580 (Add)                   (None, None, None, 3 0           bn2-7y[0][0]
#                                                                  activation_1165[0][0]
# __________________________________________________________________________________________________
# activation_1167 (Activation)    (None, None, None, 3 0           add_580[0][0]
# __________________________________________________________________________________________________
# res2-8x (Conv2D)                (None, None, None, 3 9248        activation_1167[0][0]
# __________________________________________________________________________________________________
# bn2-8x (BatchNormalization)     (None, None, None, 3 128         res2-8x[0][0]
# __________________________________________________________________________________________________
# activation_1168 (Activation)    (None, None, None, 3 0           bn2-8x[0][0]
# __________________________________________________________________________________________________
# res2-8y (Conv2D)                (None, None, None, 3 9248        activation_1168[0][0]
# __________________________________________________________________________________________________
# bn2-8y (BatchNormalization)     (None, None, None, 3 128         res2-8y[0][0]
# __________________________________________________________________________________________________
# add_581 (Add)                   (None, None, None, 3 0           bn2-8y[0][0]
#                                                                  activation_1167[0][0]
# __________________________________________________________________________________________________
# activation_1169 (Activation)    (None, None, None, 3 0           add_581[0][0]
# __________________________________________________________________________________________________
# res2-9x (Conv2D)                (None, None, None, 3 9248        activation_1169[0][0]
# __________________________________________________________________________________________________
# bn2-9x (BatchNormalization)     (None, None, None, 3 128         res2-9x[0][0]
# __________________________________________________________________________________________________
# activation_1170 (Activation)    (None, None, None, 3 0           bn2-9x[0][0]
# __________________________________________________________________________________________________
# res2-9y (Conv2D)                (None, None, None, 3 9248        activation_1170[0][0]
# __________________________________________________________________________________________________
# bn2-9y (BatchNormalization)     (None, None, None, 3 128         res2-9y[0][0]
# __________________________________________________________________________________________________
# add_582 (Add)                   (None, None, None, 3 0           bn2-9y[0][0]
#                                                                  activation_1169[0][0]
# __________________________________________________________________________________________________
# activation_1171 (Activation)    (None, None, None, 3 0           add_582[0][0]
# __________________________________________________________________________________________________
# res2-10x (Conv2D)               (None, None, None, 3 9248        activation_1171[0][0]
# __________________________________________________________________________________________________
# bn2-10x (BatchNormalization)    (None, None, None, 3 128         res2-10x[0][0]
# __________________________________________________________________________________________________
# activation_1172 (Activation)    (None, None, None, 3 0           bn2-10x[0][0]
# __________________________________________________________________________________________________
# res2-10y (Conv2D)               (None, None, None, 3 9248        activation_1172[0][0]
# __________________________________________________________________________________________________
# bn2-10y (BatchNormalization)    (None, None, None, 3 128         res2-10y[0][0]
# __________________________________________________________________________________________________
# add_583 (Add)                   (None, None, None, 3 0           bn2-10y[0][0]
#                                                                  activation_1171[0][0]
# __________________________________________________________________________________________________
# activation_1173 (Activation)    (None, None, None, 3 0           add_583[0][0]
# __________________________________________________________________________________________________
# res2-11x (Conv2D)               (None, None, None, 3 9248        activation_1173[0][0]
# __________________________________________________________________________________________________
# bn2-11x (BatchNormalization)    (None, None, None, 3 128         res2-11x[0][0]
# __________________________________________________________________________________________________
# activation_1174 (Activation)    (None, None, None, 3 0           bn2-11x[0][0]
# __________________________________________________________________________________________________
# res2-11y (Conv2D)               (None, None, None, 3 9248        activation_1174[0][0]
# __________________________________________________________________________________________________
# bn2-11y (BatchNormalization)    (None, None, None, 3 128         res2-11y[0][0]
# __________________________________________________________________________________________________
# add_584 (Add)                   (None, None, None, 3 0           bn2-11y[0][0]
#                                                                  activation_1173[0][0]
# __________________________________________________________________________________________________
# activation_1175 (Activation)    (None, None, None, 3 0           add_584[0][0]
# __________________________________________________________________________________________________
# res2-12x (Conv2D)               (None, None, None, 3 9248        activation_1175[0][0]
# __________________________________________________________________________________________________
# bn2-12x (BatchNormalization)    (None, None, None, 3 128         res2-12x[0][0]
# __________________________________________________________________________________________________
# activation_1176 (Activation)    (None, None, None, 3 0           bn2-12x[0][0]
# __________________________________________________________________________________________________
# res2-12y (Conv2D)               (None, None, None, 3 9248        activation_1176[0][0]
# __________________________________________________________________________________________________
# bn2-12y (BatchNormalization)    (None, None, None, 3 128         res2-12y[0][0]
# __________________________________________________________________________________________________
# add_585 (Add)                   (None, None, None, 3 0           bn2-12y[0][0]
#                                                                  activation_1175[0][0]
# __________________________________________________________________________________________________
# activation_1177 (Activation)    (None, None, None, 3 0           add_585[0][0]
# __________________________________________________________________________________________________
# res2-13x (Conv2D)               (None, None, None, 3 9248        activation_1177[0][0]
# __________________________________________________________________________________________________
# bn2-13x (BatchNormalization)    (None, None, None, 3 128         res2-13x[0][0]
# __________________________________________________________________________________________________
# activation_1178 (Activation)    (None, None, None, 3 0           bn2-13x[0][0]
# __________________________________________________________________________________________________
# res2-13y (Conv2D)               (None, None, None, 3 9248        activation_1178[0][0]
# __________________________________________________________________________________________________
# bn2-13y (BatchNormalization)    (None, None, None, 3 128         res2-13y[0][0]
# __________________________________________________________________________________________________
# add_586 (Add)                   (None, None, None, 3 0           bn2-13y[0][0]
#                                                                  activation_1177[0][0]
# __________________________________________________________________________________________________
# activation_1179 (Activation)    (None, None, None, 3 0           add_586[0][0]
# __________________________________________________________________________________________________
# res2-14x (Conv2D)               (None, None, None, 3 9248        activation_1179[0][0]
# __________________________________________________________________________________________________
# bn2-14x (BatchNormalization)    (None, None, None, 3 128         res2-14x[0][0]
# __________________________________________________________________________________________________
# ...
# add_599 (Add)                   (None, None, None, 6 0           bn3-8y[0][0]
#                                                                  activation_1203[0][0]
# __________________________________________________________________________________________________
# activation_1205 (Activation)    (None, None, None, 6 0           add_599[0][0]
# __________________________________________________________________________________________________
# res3-9x (Conv2D)                (None, None, None, 6 36928       activation_1205[0][0]
# __________________________________________________________________________________________________
# bn3-9x (BatchNormalization)     (None, None, None, 6 256         res3-9x[0][0]
# __________________________________________________________________________________________________
# activation_1206 (Activation)    (None, None, None, 6 0           bn3-9x[0][0]
# __________________________________________________________________________________________________
# res3-9y (Conv2D)                (None, None, None, 6 36928       activation_1206[0][0]
# __________________________________________________________________________________________________
# bn3-9y (BatchNormalization)     (None, None, None, 6 256         res3-9y[0][0]
# __________________________________________________________________________________________________
# add_600 (Add)                   (None, None, None, 6 0           bn3-9y[0][0]
#                                                                  activation_1205[0][0]
# __________________________________________________________________________________________________
# activation_1207 (Activation)    (None, None, None, 6 0           add_600[0][0]
# __________________________________________________________________________________________________
# res3-10x (Conv2D)               (None, None, None, 6 36928       activation_1207[0][0]
# __________________________________________________________________________________________________
# bn3-10x (BatchNormalization)    (None, None, None, 6 256         res3-10x[0][0]
# __________________________________________________________________________________________________
# activation_1208 (Activation)    (None, None, None, 6 0           bn3-10x[0][0]
# __________________________________________________________________________________________________
# res3-10y (Conv2D)               (None, None, None, 6 36928       activation_1208[0][0]
# __________________________________________________________________________________________________
# bn3-10y (BatchNormalization)    (None, None, None, 6 256         res3-10y[0][0]
# __________________________________________________________________________________________________
# add_601 (Add)                   (None, None, None, 6 0           bn3-10y[0][0]
#                                                                  activation_1207[0][0]
# __________________________________________________________________________________________________
# activation_1209 (Activation)    (None, None, None, 6 0           add_601[0][0]
# __________________________________________________________________________________________________
# res3-11x (Conv2D)               (None, None, None, 6 36928       activation_1209[0][0]
# __________________________________________________________________________________________________
# bn3-11x (BatchNormalization)    (None, None, None, 6 256         res3-11x[0][0]
# __________________________________________________________________________________________________
# activation_1210 (Activation)    (None, None, None, 6 0           bn3-11x[0][0]
# __________________________________________________________________________________________________
# res3-11y (Conv2D)               (None, None, None, 6 36928       activation_1210[0][0]
# __________________________________________________________________________________________________
# bn3-11y (BatchNormalization)    (None, None, None, 6 256         res3-11y[0][0]
# __________________________________________________________________________________________________
# add_602 (Add)                   (None, None, None, 6 0           bn3-11y[0][0]
#                                                                  activation_1209[0][0]
# __________________________________________________________________________________________________
# activation_1211 (Activation)    (None, None, None, 6 0           add_602[0][0]
# __________________________________________________________________________________________________
# res3-12x (Conv2D)               (None, None, None, 6 36928       activation_1211[0][0]
# __________________________________________________________________________________________________
# bn3-12x (BatchNormalization)    (None, None, None, 6 256         res3-12x[0][0]
# __________________________________________________________________________________________________
# activation_1212 (Activation)    (None, None, None, 6 0           bn3-12x[0][0]
# __________________________________________________________________________________________________
# res3-12y (Conv2D)               (None, None, None, 6 36928       activation_1212[0][0]
# __________________________________________________________________________________________________
# bn3-12y (BatchNormalization)    (None, None, None, 6 256         res3-12y[0][0]
# __________________________________________________________________________________________________
# add_603 (Add)                   (None, None, None, 6 0           bn3-12y[0][0]
#                                                                  activation_1211[0][0]
# __________________________________________________________________________________________________
# activation_1213 (Activation)    (None, None, None, 6 0           add_603[0][0]
# __________________________________________________________________________________________________
# res3-13x (Conv2D)               (None, None, None, 6 36928       activation_1213[0][0]
# __________________________________________________________________________________________________
# bn3-13x (BatchNormalization)    (None, None, None, 6 256         res3-13x[0][0]
# __________________________________________________________________________________________________
# activation_1214 (Activation)    (None, None, None, 6 0           bn3-13x[0][0]
# __________________________________________________________________________________________________
# res3-13y (Conv2D)               (None, None, None, 6 36928       activation_1214[0][0]
# __________________________________________________________________________________________________
# bn3-13y (BatchNormalization)    (None, None, None, 6 256         res3-13y[0][0]
# __________________________________________________________________________________________________
# add_604 (Add)                   (None, None, None, 6 0           bn3-13y[0][0]
#                                                                  activation_1213[0][0]
# __________________________________________________________________________________________________
# activation_1215 (Activation)    (None, None, None, 6 0           add_604[0][0]
# __________________________________________________________________________________________________
# res3-14x (Conv2D)               (None, None, None, 6 36928       activation_1215[0][0]
# __________________________________________________________________________________________________
# bn3-14x (BatchNormalization)    (None, None, None, 6 256         res3-14x[0][0]
# __________________________________________________________________________________________________
# activation_1216 (Activation)    (None, None, None, 6 0           bn3-14x[0][0]
# __________________________________________________________________________________________________
# res3-14y (Conv2D)               (None, None, None, 6 36928       activation_1216[0][0]
# __________________________________________________________________________________________________
# bn3-14y (BatchNormalization)    (None, None, None, 6 256         res3-14y[0][0]
# __________________________________________________________________________________________________
# add_605 (Add)                   (None, None, None, 6 0           bn3-14y[0][0]
#                                                                  activation_1215[0][0]
# __________________________________________________________________________________________________
# activation_1217 (Activation)    (None, None, None, 6 0           add_605[0][0]
# __________________________________________________________________________________________________
# res3-15x (Conv2D)               (None, None, None, 6 36928       activation_1217[0][0]
# __________________________________________________________________________________________________
# bn3-15x (BatchNormalization)    (None, None, None, 6 256         res3-15x[0][0]
# __________________________________________________________________________________________________
# activation_1218 (Activation)    (None, None, None, 6 0           bn3-15x[0][0]
# __________________________________________________________________________________________________
# res3-15y (Conv2D)               (None, None, None, 6 36928       activation_1218[0][0]
# __________________________________________________________________________________________________
# bn3-15y (BatchNormalization)    (None, None, None, 6 256         res3-15y[0][0]
# __________________________________________________________________________________________________
# add_606 (Add)                   (None, None, None, 6 0           bn3-15y[0][0]
#                                                                  activation_1217[0][0]
# __________________________________________________________________________________________________
# activation_1219 (Activation)    (None, None, None, 6 0           add_606[0][0]
# __________________________________________________________________________________________________
# res3-16x (Conv2D)               (None, None, None, 6 36928       activation_1219[0][0]
# __________________________________________________________________________________________________
# bn3-16x (BatchNormalization)    (None, None, None, 6 256         res3-16x[0][0]
# __________________________________________________________________________________________________
# activation_1220 (Activation)    (None, None, None, 6 0           bn3-16x[0][0]
# __________________________________________________________________________________________________
# res3-16y (Conv2D)               (None, None, None, 6 36928       activation_1220[0][0]
# __________________________________________________________________________________________________
# bn3-16y (BatchNormalization)    (None, None, None, 6 256         res3-16y[0][0]
# __________________________________________________________________________________________________
# add_607 (Add)                   (None, None, None, 6 0           bn3-16y[0][0]
#                                                                  activation_1219[0][0]
# __________________________________________________________________________________________________
# activation_1221 (Activation)    (None, None, None, 6 0           add_607[0][0]
# __________________________________________________________________________________________________
# res3-17x (Conv2D)               (None, None, None, 6 36928       activation_1221[0][0]
# __________________________________________________________________________________________________
# bn3-17x (BatchNormalization)    (None, None, None, 6 256         res3-17x[0][0]
# __________________________________________________________________________________________________
# activation_1222 (Activation)    (None, None, None, 6 0           bn3-17x[0][0]
# __________________________________________________________________________________________________
# res3-17y (Conv2D)               (None, None, None, 6 36928       activation_1222[0][0]
# __________________________________________________________________________________________________
# bn3-17y (BatchNormalization)    (None, None, None, 6 256         res3-17y[0][0]
# __________________________________________________________________________________________________
# add_608 (Add)                   (None, None, None, 6 0           bn3-17y[0][0]
#                                                                  activation_1221[0][0]
# __________________________________________________________________________________________________
# activation_1223 (Activation)    (None, None, None, 6 0           add_608[0][0]
# __________________________________________________________________________________________________
# res3-18x (Conv2D)               (None, None, None, 6 36928       activation_1223[0][0]
# __________________________________________________________________________________________________
# bn3-18x (BatchNormalization)    (None, None, None, 6 256         res3-18x[0][0]
# __________________________________________________________________________________________________
# activation_1224 (Activation)    (None, None, None, 6 0           bn3-18x[0][0]
# __________________________________________________________________________________________________
# res3-18y (Conv2D)               (None, None, None, 6 36928       activation_1224[0][0]
# __________________________________________________________________________________________________
# bn3-18y (BatchNormalization)    (None, None, None, 6 256         res3-18y[0][0]
# __________________________________________________________________________________________________
# add_609 (Add)                   (None, None, None, 6 0           bn3-18y[0][0]
#                                                                  activation_1223[0][0]
# __________________________________________________________________________________________________
# activation_1225 (Activation)    (None, None, None, 6 0           add_609[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 64)           0           activation_1225[0][0]
# __________________________________________________________________________________________________
# embedding (Dense)               (None, 100)          6500        avg_pool[0][0]
# ==================================================================================================
# Total params: 1,745,956
# Trainable params: 1,737,860
# Non-trainable params: 8,096
# __________________________________________________________________________________________________

# %%
logits_train_res = net_res.predict(x_train[:49000], verbose = 1)
# Out:
# 49000/49000 [==============================] - 1063s 22ms/step

# %%
def SoftMax(s):
    # minus max to avoid large s case
    p = np.exp(s-np.expand_dims(np.max(s,axis=1),axis=1))/\
    np.expand_dims(np.exp(s-np.expand_dims(np.max(s,axis=1),axis=1)).sum(axis=1),axis=1)  # matrix of size NxK
    return p

# %%
print(logits_train_res.shape)
print(logits_train_res[0])
y_pred_big = np.argmax(SoftMax(logits_train_res),axis=1)
y_true = np.argmax(y_train[:49000],axis=1)
print('Train accuracy of big model: {}'.format(np.mean(y_true==y_pred_big)))
# Out:
# (49000, 100)
# [-1.5965376   2.0916662  -1.7080394  -2.3401544  -1.5550946  -7.9265337
#  -1.9221675   1.0908899   3.6988983   4.865921    3.9860163  -4.4878407
#  -1.5065367   4.4253283   2.149107   -4.5261736   1.1044347  -2.214517
#  -0.60959107  2.3700893  -4.7188826   4.562145   -2.2339377  -0.43608427
#   1.4681711  -0.21188563 -2.7075388   1.8217117  -3.0712423  -1.8068831
#  -5.9322743   6.629902    3.0470107   3.1984599  -1.5094794   1.6511922
#   4.640464    4.141948   -2.356608   -4.3477554  -2.7679079   4.5643945
#  -1.0097531  -4.699317   -7.1383376  -3.9733102   5.1767006   1.4382753
#   1.668138   -1.7402356  -0.0684002   2.003531   -1.9643902  -6.250108
#  -0.2044217  -5.8434987   3.341186   -0.6098274  -0.32815063  3.3661585
#   1.5814054  -6.343765    0.4769208   2.1709983  -0.5469464  -0.8419374
#   1.518573   -1.3634694   2.8196032  -0.73783785 -3.8844328  -3.6488805
#   5.6056137   4.701839    5.568709    5.429322    2.1272514  -0.21784377
#  -0.08637193 -0.1858269   5.4145494   8.120225    0.96460116 -1.752682
#  -3.6034858   3.5843542  -5.651011    3.526272   -0.29929385  2.9089587
#  13.04074     0.78578967 -1.8016323  -1.0962541  -5.2640886  -4.750658
#   3.8401241  -4.1348495  -4.900799   -5.2507076 ]
# Train accuracy of big model: 0.9952448979591837

# %%
with open('./cifar100/resnet110_logits_train.txt', 'wb') as fp:
    pickle.dump(logits_train_res, fp)

# %%
# Predict to get logits for test
logits_test = net_res.predict(x_test, verbose = 1)
# Out:
# 10000/10000 [==============================] - 201s 20ms/step

# %%
print(logits_test[0])
y_pred_big = np.argmax(SoftMax(logits_test),axis=1)
y_true = np.argmax(y_test,axis=1)
print('Test accuracy of big model: {}'.format(np.mean(y_true==y_pred_big)))
# Out:
# [-6.068798   -4.523218   -4.731172   -1.6792998   3.5741763  -0.15125123
#  -1.2078682  -3.6526413   3.4743977  -3.005215   -3.1354995   2.5808342
#   5.7947254   2.6016715  -2.0448287   5.173783   -2.3950481   3.4126356
#  -3.6132193  -3.5915787  -6.2181554  -0.9666601   2.5290911   0.872355
#   0.7275995   0.7811909  -3.4272017  -2.6549697  -2.0854492   0.10899204
#   2.1402147   4.6930556   4.711023    3.0502515  -2.0846872   2.606184
#  -1.7049557  -0.37278196 -0.36674178  0.09816748  6.8902707  -4.270845
#   2.2859044  -0.65528595 -5.1995964  -1.9651096   5.2476544  -2.3290915
#   2.1142879   8.304985   -1.3609399   2.003549   -1.9033939  -3.1886997
#  -0.3502258  -0.5843327   4.484993   -1.893204    0.34000242  2.0272462
#   1.6472216   0.9460925  -1.1196889   1.7885422   0.69869184 -2.1220722
#   1.6792787  -0.23104388  8.554266    0.89954746 -5.844656    2.5973814
#  -2.5295947  -2.0598173  -2.4477658   1.7708652   8.152147   -0.26964808
#  -6.7581735   9.770423    3.3933237   0.15353978  3.8578472  -7.87522
#  -1.6981182  -0.79399633 -5.8026996   5.837      -5.034239    1.0824063
#   5.3449287   0.1841748   1.0007453  -0.9710129  -4.7639112   2.070578
#  -2.3781493  -1.5095502  -3.806427   -2.6590686 ]
# Test accuracy of big model: 0.7321

# %%
# For being faster pick up file of logits from resnet110
logits_train_res = unpickle('./cifar100/resnet110_logits_train.txt')

# %%
# Train small model with distilling from ResNet110
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=5.0,logit_distill=logits_train_res,
                      checkpoint_name='checkpoints/distill_model_cifar100')

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 59.873581
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_0.pkl"
# (Epoch 0 / 2) train acc: 0.013327; val_acc: 0.015000
# (Iteration 101 / 980) loss: 56.560818
# (Iteration 201 / 980) loss: 55.696028
# (Iteration 301 / 980) loss: 54.858248
# (Iteration 401 / 980) loss: 54.276219
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_1.pkl"
# (Epoch 1 / 2) train acc: 0.224857; val_acc: 0.183000
# (Iteration 501 / 980) loss: 54.723139
# (Iteration 601 / 980) loss: 52.461798
# (Iteration 701 / 980) loss: 52.780953
# (Iteration 801 / 980) loss: 53.014063
# (Iteration 901 / 980) loss: 52.673768
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_2.pkl"
# (Epoch 2 / 2) train acc: 0.310224; val_acc: 0.261000
# Execution time:  1475.1574792861938
# Test accuracy: 0.2802

# %%
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=2.0,logit_distill=logits_train_res,
                      checkpoint_name='checkpoints/distill_model_cifar100')

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 11.519195
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_0.pkl"
# (Epoch 0 / 2) train acc: 0.013551; val_acc: 0.020000
# (Iteration 101 / 980) loss: 9.875374
# (Iteration 201 / 980) loss: 8.976517
# (Iteration 301 / 980) loss: 8.953095
# (Iteration 401 / 980) loss: 9.079626
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_1.pkl"
# (Epoch 1 / 2) train acc: 0.231592; val_acc: 0.205000
# (Iteration 501 / 980) loss: 8.623214
# (Iteration 601 / 980) loss: 7.994780
# (Iteration 701 / 980) loss: 8.240799
# (Iteration 801 / 980) loss: 7.790274
# (Iteration 901 / 980) loss: 7.640798
# Saving checkpoint to "checkpoints/distill_model_cifar100_epoch_2.pkl"
# (Epoch 2 / 2) train acc: 0.311776; val_acc: 0.249000
# Execution time:  1504.2091999053955
# Test accuracy: 0.2694

# %%
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                 hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=20.0,logit_distill=logits_train_res)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 923.342696
# (Epoch 0 / 2) train acc: 0.014327; val_acc: 0.007000
# (Iteration 101 / 980) loss: 921.857613
# (Iteration 201 / 980) loss: 921.056706
# (Iteration 301 / 980) loss: 920.527488
# (Iteration 401 / 980) loss: 920.742419
# (Epoch 1 / 2) train acc: 0.251816; val_acc: 0.227000
# (Iteration 501 / 980) loss: 919.912761
# (Iteration 601 / 980) loss: 920.733250
# (Iteration 701 / 980) loss: 920.239117
# (Iteration 801 / 980) loss: 919.971648
# (Iteration 901 / 980) loss: 919.344459
# (Epoch 2 / 2) train acc: 0.327082; val_acc: 0.284000
# Execution time:  1500.6566090583801
# Test accuracy: 0.2822

# %% [markdown]
# # Distill knowledge from VGG

# %%
import keras
from keras.datasets import cifar100

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = keras.utils.to_categorical(y_train, 100)
y_test = keras.utils.to_categorical(y_test, 100)

# %%
# Verify shape of data
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 100)
# (10000, 32, 32, 3) (10000, 100)

# %%
net_vgg = cifar100vgg(train=False)

# %%
net_vgg.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# activation_10 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# activation_13 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_14 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               51300
# _________________________________________________________________
# activation_15 (Activation)   (None, 100)               0
# =================================================================
# Total params: 15,047,588
# Trainable params: 15,038,116
# Non-trainable params: 9,472
# _________________________________________________________________

# %%
x_train, x_test = net_vgg.normalize(x_train,x_test)
# Out:
# 121.93584
# 68.38902

# %%
# Predict  test
prob_test = net_vgg.model.predict(x_test, verbose = 1)
# Out:
# 10000/10000 [==============================] - 112s 11ms/step

# %%
print(sum(prob_test[0]))
y_pred_big = np.argmax(prob_test,axis=1)
y_true = np.argmax(y_test,axis=1)
print('Test accuracy of big model: {}'.format(np.mean(y_true==y_pred_big)))
# Out:
# 0.9999999016124406
# Test accuracy of big model: 0.7048

# %%
net_vgg_woSM = Model(inputs=net_vgg.model.input, outputs=net_vgg.model.layers[-2].output)

# %%
# Predict to get logits for test
logits_test = net_vgg_woSM.predict(x_test, verbose = 1)
# Out:
# 10000/10000 [==============================] - 124s 12ms/step

# %%
print(logits_test.shape)
print(logits_test[0])
y_pred_big = np.argmax(SoftMax(logits_test),axis=1)
y_true = np.argmax(y_test,axis=1)
print('Test accuracy of big model: {}'.format(np.mean(y_true==y_pred_big)))
# Out:
# (10000, 100)
# [-1.1773857  -2.3598697   1.379565    1.7740533  -0.43864304 -4.053173
#  -2.957971    1.0075067   5.64918    -2.6610117  -4.3843617  -1.078161
#   6.2216654  -1.3275986  -2.4417372   3.7754247  -1.8505068   4.599816
#   2.036851    1.7919738  -5.447965   -0.79682076  0.80301005  1.6044474
#  -2.500914   -3.6765857  -0.91894567  1.3104973  -4.375844   -1.4203635
#   2.317135    1.5534563  -2.6738296   2.795367   -0.7494376  -1.8716614
#  -3.869698    3.1157846   1.8392999  -3.396057    0.19659424  0.18485183
#  -2.5569162  -1.676392    1.4789174  -3.97746     2.8022676  -1.7627606
#   0.5107993   4.509336   -3.742899    0.49826813 -0.8908025  -1.6613612
#  -1.9512595   2.3769374   1.4075581  -0.28709927 -1.6575047   2.83997
#   7.7976484  -2.7571177  -3.3368654  -1.2154697  -0.9536209  -0.10844386
#  -4.472899   -0.8980129  10.274249    5.9781027  -0.03573143  5.0046697
#   5.292143    0.45626858 -2.348977   -2.4027076   4.855569    5.6626554
#  -0.88871896  6.448552    2.3205538  -0.33526862  0.88529325 -4.3539004
#  -4.3881507   0.5426203  -6.448371   -1.1999631  -4.638034    2.3738647
#   7.0091763  -0.86912256 -0.23844647  1.167546   -3.6471043  -0.5066397
#  -1.536159   -3.1962361  -2.9112654   3.1617913 ]
# Test accuracy of big model: 0.7048

# %%
# Predict to get logits for train data to prepare to distill
logits_train_vgg = net_vgg_woSM.predict(x_train[:49000], verbose = 1)
# Out:
# 49000/49000 [==============================] - 593s 12ms/step

# %%
print(logits_train_vgg[0])
y_pred_big = np.argmax(SoftMax(logits_train_vgg),axis=1)
y_true = np.argmax(y_train[:49000],axis=1)
print('Test accuracy of big model: {}'.format(np.mean(y_true==y_pred_big)))
# Out:
# [-3.6869254e+00 -9.9567795e-01 -3.7708497e-01  6.7680111e+00
#   7.0529473e-01 -2.3600364e+00 -1.5549344e-01  9.8614573e-01
#   6.2138867e-01 -1.3383497e+00 -9.2372143e-01  2.5031939e+00
#  -9.4144213e-01  1.4102044e+00  4.4262552e+00  7.3418713e+00
#  -4.0618072e+00  2.9724872e-01 -5.0880604e+00  1.8497730e+01
#   1.0002916e+00 -1.2709975e-02 -6.9960408e+00 -5.6045527e+00
#  -2.9017096e+00 -4.3465281e-01  1.5875976e+00 -3.5531640e+00
#  -2.3916948e-01  7.2946680e-01 -5.0264592e+00  5.4473872e+00
#   4.7827392e+00  2.1768814e-01  7.4618239e+00 -1.1913402e+00
#  -1.3756633e-01  2.6253901e+00  8.6846657e+00 -1.3063462e+01
#  -1.1678722e+00  3.2733631e+00  1.8129163e+00  3.7221885e+00
#  -1.4965668e+00 -5.3872437e+00  5.6498661e+00 -3.4365425e+00
#   1.4811699e+00 -2.8586533e+00  9.4321239e-01  4.7666812e+00
#  -1.8643762e+00 -2.3422599e+00 -3.9670011e-01  5.9071261e-01
#   7.6323128e-01 -3.8382895e+00  3.6487432e+00 -3.6542647e+00
#  -1.1571419e-01 -4.9820099e+00  3.0264869e+00 -4.5632582e+00
#   1.2380736e+00  6.1251316e+00 -1.3741834e-01  1.4740120e+00
#  -3.7964644e+00  1.6761621e+00 -3.4904807e+00 -3.7589293e+00
#   1.2292503e+00 -6.6506517e-01  2.6249564e+00  3.9682236e+00
#  -6.6307821e+00  1.1646043e+00 -6.0585179e+00  1.7877694e+00
#   9.9534988e-02 -5.1539774e+00  5.0712519e+00 -4.5721560e+00
#   5.1296644e+00  1.3293504e+00 -6.5799479e+00  3.2949433e+00
#   9.1078532e-01  3.6775947e+00 -1.3770657e+00 -1.6610177e+00
#   1.7758746e+00 -7.0982212e-01 -1.0570813e+00 -2.1550698e+00
#  -2.5964644e+00  3.3201637e+00 -7.4482667e-01 -5.5675535e+00]
# Test accuracy of big model: 0.9964285714285714

# %%
with open('./cifar100/vgg_logits_train.txt', 'wb') as fp:
    pickle.dump(logits_train_vgg, fp)

# %%
# For being faster pick up file of logit from vgg16
logits_train_vgg = unpickle('./cifar100/vgg_logits_train.txt')

# %%
# Repare data for training small model
data = {'X_train': x_train[:49000].transpose(0,3,1,2).copy(), 'y_train': np.argmax(y_train[:49000],axis=1),
        'X_val': x_train[49000:].transpose(0,3,1,2).copy(), 'y_val': np.argmax(y_train[49000:],axis=1),
        'X_test': x_test.transpose(0,3,1,2).copy(), 'y_test': np.argmax(y_test,axis=1),
       }

# %%
# Train small model without distilling from VGG
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                              hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

small_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100)
tic = time.time()
small_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(small_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 4.611179
# (Epoch 0 / 2) train acc: 0.012082; val_acc: 0.016000
# (Iteration 101 / 980) loss: 3.808190
# (Iteration 201 / 980) loss: 3.663060
# (Iteration 301 / 980) loss: 3.430246
# (Iteration 401 / 980) loss: 3.501492
# (Epoch 1 / 2) train acc: 0.232959; val_acc: 0.214000
# (Iteration 501 / 980) loss: 3.307973
# (Iteration 601 / 980) loss: 3.057731
# (Iteration 701 / 980) loss: 3.279852
# (Iteration 801 / 980) loss: 2.956263
# (Iteration 901 / 980) loss: 2.969794
# (Epoch 2 / 2) train acc: 0.300633; val_acc: 0.236000
# Execution time:  1384.906968832016
# Test accuracy: 0.2679

# %%
# Train small model with distilling from VGG
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                              hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=5.0,logit_distill=logits_train_vgg)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 59.873586
# (Epoch 0 / 2) train acc: 0.012102; val_acc: 0.009000
# (Iteration 101 / 980) loss: 58.185014
# (Iteration 201 / 980) loss: 57.930904
# (Iteration 301 / 980) loss: 57.435695
# (Iteration 401 / 980) loss: 57.035439
# (Epoch 1 / 2) train acc: 0.239449; val_acc: 0.213000
# (Iteration 501 / 980) loss: 56.381810
# (Iteration 601 / 980) loss: 56.496848
# (Iteration 701 / 980) loss: 56.395677
# (Iteration 801 / 980) loss: 56.058263
# (Iteration 901 / 980) loss: 56.434930
# (Epoch 2 / 2) train acc: 0.326184; val_acc: 0.249000
# Execution time:  1373.5005910396576
# Test accuracy: 0.2851

# %%
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                              hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=2.0,logit_distill=logits_train_vgg)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 11.519137
# (Epoch 0 / 2) train acc: 0.016286; val_acc: 0.023000
# (Iteration 101 / 980) loss: 9.913101
# (Iteration 201 / 980) loss: 9.217385
# (Iteration 301 / 980) loss: 8.961465
# (Iteration 401 / 980) loss: 8.390139
# (Epoch 1 / 2) train acc: 0.231735; val_acc: 0.211000
# (Iteration 501 / 980) loss: 8.452644
# (Iteration 601 / 980) loss: 8.163462
# (Iteration 701 / 980) loss: 8.318298
# (Iteration 801 / 980) loss: 8.502651
# (Iteration 901 / 980) loss: 7.830879
# (Epoch 2 / 2) train acc: 0.307000; val_acc: 0.250000
# Execution time:  1367.8328320980072
# Test accuracy: 0.2609

# %%
small_net = ThreeLayerConvNet(input_dim=(3, 32, 32), num_filters=16, filter_size=5,
                              hidden_dim=512, num_classes=100, reg=0.001, weight_scale=0.1)

distill_model = myModel(small_net, data, 
                      num_epochs=2, batch_size=100,
                      optimizer='adam',
                      optim_config={
                          'learning_rate': 1e-3,},
                      verbose=True, print_every=100,
                      temperature=20.0,logit_distill=logits_train_vgg)

tic = time.time()
distill_model.train()
toc = time.time()
print('Execution time: ',toc-tic)
print('Test accuracy: {}'.format(distill_model.check_accuracy(data['X_test'],data['y_test'])))
# Out:
# (Iteration 1 / 980) loss: 923.342945
# (Epoch 0 / 2) train acc: 0.019510; val_acc: 0.012000
# (Iteration 101 / 980) loss: 922.124840
# (Iteration 201 / 980) loss: 921.592591
# (Iteration 301 / 980) loss: 921.630974
# (Iteration 401 / 980) loss: 921.394343
# (Epoch 1 / 2) train acc: 0.244857; val_acc: 0.238000
# (Iteration 501 / 980) loss: 921.246561
# (Iteration 601 / 980) loss: 921.265330
# (Iteration 701 / 980) loss: 921.407883
# (Iteration 801 / 980) loss: 921.448293
# (Iteration 901 / 980) loss: 920.884021
# (Epoch 2 / 2) train acc: 0.305184; val_acc: 0.243000
# Execution time:  1372.3521888256073
# Test accuracy: 0.269
