# %%
from resnet164 import ResNet164
from utils import load_mnist
import numpy as np
import tensorflow as tf
import h5py
# Out:
# Using TensorFlow backend.

# %%
def evaluate(prediction, true_label):
    '''
    Returns the test accuracy.

    Args:
        prediction - 2D numpy array (Number of samples, Class)
        y_test - 2D numpy array (Number of samples, Class)

    Returns:
        Test accuracy (float)
    '''
    pred_indices = np.argmax(prediction, 1)
    true_indices = np.argmax(true_label, 1)

    return np.mean(pred_indices == true_indices)

# %%
model = ResNet164()

model.compile()
model.load_weights('ResNet164.h5')
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_mnist()

# %%
prediction = model.predict(x_test, verbose = 1)
# Out:
# 10000/10000 [==============================] - 370s 37ms/step

# %%
prediction[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bd2beb621af9> in <module>
# ----> 1 prediction[0].shape
#
# NameError: name 'prediction' is not defined

# %%
print(prediction[0])
accuracy = evaluate(prediction, y_test)
print(f'Evaluation:', accuracy * 100, '%')
# Out:
# [1.2004220e-09 1.6784691e-07 6.5072840e-08 5.9421293e-08 1.2507778e-08
#  3.5402337e-10 2.0802730e-12 9.9999952e-01 1.4756117e-10 2.1706613e-07]
# Evaluation: 99.7 %

# %%
model = tf.keras.models.load_model('ResNet164.h5')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 32, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   160         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# ...

# %% [markdown]
# # Load weight and bias at each layer

# %%
f = h5py.File('ResNet164.h5', 'r')

# %%
print(list(f.keys()))
# Out:
# ['model_weights', 'optimizer_weights']

# %%
w = f['model_weights']['dense_1']['dense_1']['kernel:0']
b = f['model_weights']['dense_1']['dense_1']['bias:0']

# %%
print(list(wei['dense_1']['dense_1']))
# Out:
# ['bias:0', 'kernel:0']

# %%
print(w.shape, b.shape)
# Out:
# (256, 10) (10,)
